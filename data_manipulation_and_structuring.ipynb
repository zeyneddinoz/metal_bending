# %% [markdown]
# ***
# # Import Libraries

# %%
import pandas as pd

import sys
import pickle
import os

pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.width', 1000)

# %% [markdown]
# ***
# # Loading Dataset
#
# ## Machine Settings

# %%
directory_of_data = os.path.join('Daten', 'Experiments')
directory_of_data
# Out:
# 'Daten/Experiments'

# %%
directory_of_machine_settings = os.path.join(directory_of_data, '_Parameter', 'Parameter_1-318.csv')
directory_of_machine_settings
# Out:
# 'Daten/Experiments/_Parameter/Parameter_1-318.csv'

# %%
# Read the machine setting CSV file:
machine_settings_dataframe = pd.read_csv(directory_of_machine_settings)
# Remove settings had error comment:
machine_settings_dataframe = machine_settings_dataframe[machine_settings_dataframe['Comments'].isna()]
# Remove redundant last row:
machine_settings_dataframe = machine_settings_dataframe[0:machine_settings_dataframe.shape[0]-1]
# Reindex rows starting from 1:
machine_settings_dataframe.index = [_ for _ in range(1, machine_settings_dataframe.shape[0]+1)]
# Drop the 'Comments' column:
machine_settings_dataframe = machine_settings_dataframe.drop(columns=['Comments'])
# Make Experiment column values integer format: 
machine_settings_dataframe.Experiment = machine_settings_dataframe.Experiment.astype(int)
machine_settings_dataframe
# Out:
#      Experiment   Tube  Outer-diameter  Wall-thickness  Target-angle  Wiper-die shortening  Pressure-die lateral position  Pressure-die distance  Pressure-die boost  Mandrel position  Mandrel retraction timing  Collet boost  Clamp-die lateral position
# 1             2  106.0            22.0             1.0          47.0                   5.0                         -50.45                    0.3                 0.0           -2909.8                        2.0          0.85                      225.25
# 2             3  105.0            22.0             1.0          47.0                   5.0                         -50.45                    0.3                 0.0           -2909.8                        2.0          0.85                      225.25
# 3             4  104.0            22.0             1.0          47.0                   5.0                         -50.45                    0.3                 0.0           -2909.6                        2.0          0.85                      225.25
# 4             5  103.0            22.0             1.0          47.0                   5.0                         -50.45                    0.3                 0.0           -2909.6                        2.0          0.85                      225.25
# 5             6  102.0            22.0             1.0          47.0                   5.0                         -50.45                    0.3                 0.0           -2909.4                        2.0          0.85                      225.25
# ..          ...    ...             ...             ...           ...                   ...                            ...                    ...                 ...               ...                        ...           ...                         ...
# 311         314  219.0            22.0             1.0          47.0                   5.0                         -50.45                    0.6                 0.9           -2905.6                        2.0          0.90                      225.40
# 312         315  218.0            22.0             1.0          47.0                   5.0                         -50.45                    0.6                 0.9           -2905.6                        2.0          0.90                      225.40
# 313         316  217.0            22.0             1.0          47.0                   5.0                         -50.45                    0.6                 0.9           -2905.6                        2.0          0.90                      225.40
# 314         317  216.0            22.0             1.0          47.0                   5.0                         -50.45                    0.6                 0.9           -2907.6                        2.0          0.90                      225.40
# 315         318  215.0            22.0             1.0          47.0                   5.0                         -50.45                    0.6                 0.9           -2907.6                        2.0          0.90                      225.40
#
# [315 rows x 13 columns]

# %% [markdown]
# ## Helper loading functions:

# %%
def geo_file_names_to_dataframe(geometry_files, setting_num):

    # Initialize an empty list to hold individual dataframes
    geo_dataframes = []
    
    for geo_file_name in geometry_files:
    
        geo_file_path = os.path.join(directory_of_data, str(setting_num), geo_file_name)
    
        # Extract the section name from the filename
        section = geo_file_name.split('GEOMETRY_SECTION_')[1].replace('.csv', '')
    
        geo_result_dataframe = pd.read_csv(geo_file_path, sep=';')
    
        # Add the 'Section' column
        geo_result_dataframe['Section'] = section
        
        # Append to the list
        geo_dataframes.append(geo_result_dataframe)
    
    
    # Concatenate all dataframes into one
    geometry_results_dataframe = pd.concat(geo_dataframes, ignore_index=True)
    
    # Display the first few rows to verify
    return geometry_results_dataframe

# %%
def process_load_files(load_files, setting_num):
    # Separate files into MACHINE and SENSOR groups
    machine_files = [f for f in load_files if 'MACHINE' in f]
    sensor_files = [f for f in load_files if 'SENSOR' in f]

    def process_group(files):
        dfs = []
        for file in files:
            # Extract section name from filename (e.g., "MACHINE_CLAMP-DIE_LATERAL" from "EXP_318_LOAD_MACHINE_CLAMP-DIE_LATERAL.csv")
            section = file.split('_LOAD_')[1].replace('.csv', '')
            
            # Read CSV without headers to retain all rows
            try:
                df = pd.read_csv(
                    os.path.join(directory_of_data, str(setting_num), file), 
                    sep=';', 
                    header=None,
                    encoding='latin-1'  # Fallback encoding
                )
            except UnicodeDecodeError:
                df = pd.read_csv(
                    os.path.join(directory_of_data, str(setting_num), file), 
                    sep=';', 
                    header=None,
                    encoding='utf-8'
                )
            
            # Extract parameter-unit from the first row (e.g., "Max Torque [%]")
            parameter_unit = df.iloc[0, 1]
            
            # Rename columns to include section and parameter-unit
            new_col_name = f"{section}_{parameter_unit.replace(' ', '_')}"
            df.columns = ['Time', new_col_name]
            
            dfs.append(df)
        
        # Merge all dataframes on Time (outer merge to retain all rows)
        if dfs:
            merged_df = dfs[0]
            for df in dfs[1:]:
                merged_df = pd.merge(merged_df, df, on='Time', how='outer')
            
            # Sort by Time (strings like "Time [s]" will appear at the end)
            merged_df['Time'] = pd.to_numeric(merged_df['Time'], errors='coerce')
            merged_df.sort_values('Time', inplace=True, na_position='last')
            merged_df['Time'] = merged_df['Time'].astype(str)
            merged_df.rename(columns={'Time': 'Time_[s]'}, inplace=True)
            merged_df.reset_index(drop=True, inplace=True)
            return merged_df
        else:
            return pd.DataFrame()

    # Process MACHINE and SENSOR files separately
    machine_df = process_group(machine_files)
    sensor_df = process_group(sensor_files)

    # Drop the last row (header remnants)
    if not machine_df.empty:
        machine_df = machine_df.drop(machine_df.index[-1])
    if not sensor_df.empty:
        sensor_df = sensor_df.drop(sensor_df.index[-1])

    return machine_df, sensor_df

# %%
def movement_file_names_to_dataframe(movement_files, setting_num):
    # List to hold individual dataframes
    dfs = []
    
    for movement_file in movement_files:
        # Construct full file path
        movement_file_path = os.path.join(directory_of_data, str(setting_num), movement_file)
        
        # Extract section name from filename (e.g., "COLLET_AXIAL" from "MOVEMENT_MACHINE_COLLET_AXIAL.csv")
        section = movement_file.split('MOVEMENT_MACHINE_')[1].replace('.csv', '')
        
        # Read CSV with correct encoding
        try:
            df = pd.read_csv(movement_file_path, sep=';', header=None, encoding='utf-8')
        except UnicodeDecodeError:
            # Fallback to latin-1 if utf-8 fails
            df = pd.read_csv(movement_file_path, sep=';', header=None, encoding='latin-1')
        
        # Extract parameter-unit from first row (e.g., "Displacement [mm]")
        parameter_unit = df.iloc[0, 1]
        
        # Create new column name
        new_col_name = f"{section}_{parameter_unit.replace(' ', '_')}"
        df.columns = ['Time', new_col_name]
        
        dfs.append(df)
    
    # Merge all dataframes
    if dfs:
        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df, on='Time', how='outer')
        
        # Sort and clean Time column
        merged_df['Time'] = pd.to_numeric(merged_df['Time'], errors='coerce')
        merged_df.sort_values('Time', inplace=True, na_position='last')
        merged_df['Time'] = merged_df['Time'].astype(str)
        merged_df.rename(columns={'Time': 'Time_[s]'}, inplace=True)
        merged_df.reset_index(drop=True, inplace=True)
        
        # Drop the last row (header remnant)
        merged_df = merged_df.drop(merged_df.index[-1])
    else:
        merged_df = pd.DataFrame()
    
    return merged_df

# %%
def process_feature_geometry_files(feature_files, setting_num):
    # List to hold individual DataFrames
    feature_dfs = []
    
    for feature_file in feature_files:
        # Extract feature type from filename (e.g., 'ARC' from 'EXP_2_GEOMETRY_FEATURE_ARC.csv')
        if 'ARC' in feature_file:
            feature = 'ARC'
        elif 'LINEAR-1' in feature_file:
            feature = 'LINEAR-1'
        elif 'LINEAR-2' in feature_file:
            feature = 'LINEAR-2'
        else:
            continue  # Skip invalid files
        
        # Read the CSV file
        feature_path = os.path.join(directory_of_data, str(setting_num), feature_file)
        df = pd.read_csv(feature_path, sep=';')
        
        # Rename the first column to 'Angle[degree]ORDistance[mm]'
        df.rename(columns={df.columns[0]: 'Angle[degree]ORDistance[mm]'}, inplace=True)
        
        # Add the 'Feature' column
        df['Feature'] = feature
        
        feature_dfs.append(df)
    
    # Concatenate all DataFrames
    if feature_dfs:
        geo_feature_result_df = pd.concat(feature_dfs, ignore_index=True)
        return geo_feature_result_df
    else:
        return pd.DataFrame()

# %% [markdown]
# ## Dictionary preparetion:

# %%
experiments_process_and_results = {}


for setting_num in machine_settings_dataframe.Experiment:
    print(f'The experiment number is {setting_num}')
    
    experiments_process_and_results[f'Exp_{setting_num}'] = {}
    
    # ... [existing initialization code] ...

    # List all files and filter CSVs (DO NOT exclude the first 3 files)
    files = os.listdir(os.path.join(directory_of_data, str(setting_num)))
    csv_files = sorted([file for file in files if file.endswith('.csv')])
    
    # Separate into groups
    feature_geometry_files = [f for f in csv_files if 'GEOMETRY_FEATURE' in f]
    section_geometry_files = [f for f in csv_files if 'GEOMETRY_SECTION' in f][:-1]  # Exclude SPRINGBACK
    load_files = [f for f in csv_files if 'LOAD' in f]
    movement_files = [f for f in csv_files if 'MOVEMENT' in f]
    
    # Process all groups
    geo_feature_result_df = process_feature_geometry_files(feature_geometry_files, setting_num)
    geo_result_df = geo_file_names_to_dataframe(section_geometry_files, setting_num)
    machine_df, sensor_df = process_load_files(load_files, setting_num)
    movement_results_df = movement_file_names_to_dataframe(movement_files, setting_num)
    
    # Save to the results dictionary
    experiments_process_and_results[f'Exp_{setting_num}']['geometry_features'] = geo_feature_result_df
    experiments_process_and_results[f'Exp_{setting_num}']['geometry_result'] = geo_result_df
    experiments_process_and_results[f'Exp_{setting_num}']['load_machine_process'] = machine_df
    experiments_process_and_results[f'Exp_{setting_num}']['load_sensor_process'] = sensor_df
    experiments_process_and_results[f'Exp_{setting_num}']['movement'] = movement_results_df
# Out:
# The experiment number is 2
# The experiment number is 3
# The experiment number is 4
# The experiment number is 5
# The experiment number is 6
# The experiment number is 7
# The experiment number is 8
# The experiment number is 9
# The experiment number is 10
# The experiment number is 11
# The experiment number is 12
# The experiment number is 13
# The experiment number is 14
# The experiment number is 15
# The experiment number is 16
# The experiment number is 17
# The experiment number is 18
# The experiment number is 19
# The experiment number is 20
# The experiment number is 21
# The experiment number is 22
# The experiment number is 23
# The experiment number is 24
# The experiment number is 25
# The experiment number is 26
# The experiment number is 27
# The experiment number is 28
# The experiment number is 29
# The experiment number is 30
# The experiment number is 31
# The experiment number is 32
# The experiment number is 33
# The experiment number is 34
# The experiment number is 35
# The experiment number is 36
# The experiment number is 37
# The experiment number is 38
# The experiment number is 39
# The experiment number is 40
# The experiment number is 41
# The experiment number is 42
# The experiment number is 43
# The experiment number is 44
# The experiment number is 45
# The experiment number is 46
# The experiment number is 47
# The experiment number is 49
# The experiment number is 50
# The experiment number is 51
# The experiment number is 52
# The experiment number is 53
# The experiment number is 54
# The experiment number is 55
# The experiment number is 56
# The experiment number is 57
# The experiment number is 58
# The experiment number is 59
# The experiment number is 60
# The experiment number is 61
# The experiment number is 62
# The experiment number is 63
# The experiment number is 64
# The experiment number is 65
# The experiment number is 66
# The experiment number is 67
# The experiment number is 68
# The experiment number is 69
# The experiment number is 70
# The experiment number is 71
# The experiment number is 72
# The experiment number is 73
# The experiment number is 74
# The experiment number is 75
# The experiment number is 76
# The experiment number is 77
# The experiment number is 78
# The experiment number is 79
# The experiment number is 80
# The experiment number is 81
# The experiment number is 82
# The experiment number is 83
# The experiment number is 84
# The experiment number is 85
# The experiment number is 86
# The experiment number is 87
# The experiment number is 88
# The experiment number is 89
# The experiment number is 90
# The experiment number is 91
# The experiment number is 92
# The experiment number is 93
# The experiment number is 94
# The experiment number is 95
# The experiment number is 96
# The experiment number is 97
# The experiment number is 98
# The experiment number is 99
# The experiment number is 100
# The experiment number is 101
# The experiment number is 102
# The experiment number is 103
# The experiment number is 104
# The experiment number is 105
# The experiment number is 106
# The experiment number is 107
# The experiment number is 108
# The experiment number is 109
# The experiment number is 110
# The experiment number is 111
# The experiment number is 112
# The experiment number is 113
# The experiment number is 114
# The experiment number is 115
# The experiment number is 116
# The experiment number is 117
# The experiment number is 118
# The experiment number is 119
# The experiment number is 120
# The experiment number is 121
# The experiment number is 122
# The experiment number is 123
# The experiment number is 124
# The experiment number is 125
# The experiment number is 126
# The experiment number is 127
# The experiment number is 128
# The experiment number is 129
# The experiment number is 130
# The experiment number is 131
# The experiment number is 132
# The experiment number is 133
# The experiment number is 134
# The experiment number is 135
# The experiment number is 136
# The experiment number is 137
# The experiment number is 138
# The experiment number is 139
# The experiment number is 140
# The experiment number is 141
# The experiment number is 142
# The experiment number is 143
# The experiment number is 144
# The experiment number is 145
# The experiment number is 146
# The experiment number is 147
# The experiment number is 148
# The experiment number is 149
# The experiment number is 150
# The experiment number is 151
# The experiment number is 152
# The experiment number is 153
# The experiment number is 154
# The experiment number is 155
# The experiment number is 156
# The experiment number is 157
# The experiment number is 158
# The experiment number is 159
# The experiment number is 160
# The experiment number is 161
# The experiment number is 162
# The experiment number is 163
# The experiment number is 164
# The experiment number is 165
# The experiment number is 167
# The experiment number is 168
# The experiment number is 169
# The experiment number is 170
# The experiment number is 171
# The experiment number is 172
# The experiment number is 173
# The experiment number is 174
# The experiment number is 175
# The experiment number is 176
# The experiment number is 177
# The experiment number is 178
# The experiment number is 179
# The experiment number is 180
# The experiment number is 181
# The experiment number is 182
# The experiment number is 183
# The experiment number is 184
# The experiment number is 185
# The experiment number is 186
# The experiment number is 187
# The experiment number is 188
# The experiment number is 189
# The experiment number is 190
# The experiment number is 191
# The experiment number is 192
# The experiment number is 193
# The experiment number is 194
# The experiment number is 195
# The experiment number is 196
# The experiment number is 197
# The experiment number is 198
# The experiment number is 199
# The experiment number is 200
# The experiment number is 201
# The experiment number is 202
# The experiment number is 203
# The experiment number is 204
# The experiment number is 205
# The experiment number is 206
# The experiment number is 207
# The experiment number is 208
# The experiment number is 209
# The experiment number is 210
# The experiment number is 211
# The experiment number is 212
# The experiment number is 213
# The experiment number is 214
# The experiment number is 215
# The experiment number is 216
# The experiment number is 217
# The experiment number is 218
# The experiment number is 219
# The experiment number is 220
# The experiment number is 221
# The experiment number is 222
# The experiment number is 223
# The experiment number is 224
# The experiment number is 225
# The experiment number is 226
# The experiment number is 227
# The experiment number is 228
# The experiment number is 229
# The experiment number is 230
# The experiment number is 231
# The experiment number is 232
# The experiment number is 233
# The experiment number is 234
# The experiment number is 235
# The experiment number is 236
# The experiment number is 237
# The experiment number is 238
# The experiment number is 239
# The experiment number is 240
# The experiment number is 241
# The experiment number is 242
# The experiment number is 243
# The experiment number is 244
# The experiment number is 245
# The experiment number is 246
# The experiment number is 247
# The experiment number is 248
# The experiment number is 249
# The experiment number is 250
# The experiment number is 251
# The experiment number is 252
# The experiment number is 253
# The experiment number is 254
# The experiment number is 255
# The experiment number is 256
# The experiment number is 257
# The experiment number is 258
# The experiment number is 259
# The experiment number is 260
# The experiment number is 261
# The experiment number is 262
# The experiment number is 263
# The experiment number is 264
# The experiment number is 265
# The experiment number is 266
# The experiment number is 267
# The experiment number is 268
# The experiment number is 269
# The experiment number is 270
# The experiment number is 271
# The experiment number is 272
# The experiment number is 273
# The experiment number is 274
# The experiment number is 275
# The experiment number is 276
# The experiment number is 277
# The experiment number is 278
# The experiment number is 279
# The experiment number is 280
# The experiment number is 281
# The experiment number is 282
# The experiment number is 283
# The experiment number is 284
# The experiment number is 285
# The experiment number is 286
# The experiment number is 287
# The experiment number is 288
# The experiment number is 289
# The experiment number is 290
# The experiment number is 291
# The experiment number is 292
# The experiment number is 293
# The experiment number is 294
# The experiment number is 295
# The experiment number is 296
# The experiment number is 297
# The experiment number is 298
# The experiment number is 299
# The experiment number is 300
# The experiment number is 301
# The experiment number is 302
# The experiment number is 303
# The experiment number is 304
# The experiment number is 305
# The experiment number is 306
# The experiment number is 307
# The experiment number is 308
# The experiment number is 309
# The experiment number is 310
# The experiment number is 311
# The experiment number is 312
# The experiment number is 313
# The experiment number is 314
# The experiment number is 315
# The experiment number is 316
# The experiment number is 317
# The experiment number is 318

# %% [markdown]
# ***
# ## Experiment of usage:

# %%
experiments_process_and_results['Exp_303']['geometry_features'] # machine_setting, load_machine_process, load_sensor_process, movement, and geometry_result, geometry_features
# Out:
#      Angle[degree]ORDistance[mm]  Secondary-axis [mm]  Main-axis [mm]  Out-of-roundness [-]  Collapse [mm]   Feature
# 0                            0.0            22.224602       21.868478              0.016157      -0.173220       ARC
# 1                            1.0            22.214915       21.861608              0.016029      -0.180090       ARC
# 2                            2.0            22.207792       21.845594              0.016432      -0.196105       ARC
# 3                            3.0            22.203166       21.818703              0.017442      -0.222995       ARC
# 4                            4.0            22.199262       21.773926              0.019297      -0.267772       ARC
# ..                           ...                  ...             ...                   ...            ...       ...
# 116                         42.0            22.288183       21.877241              0.018644      -0.164457  LINEAR-2
# 117                         44.0            22.320377       21.890924              0.019484      -0.150774  LINEAR-2
# 118                         46.0            22.282348       21.904174              0.017157      -0.137524  LINEAR-2
# 119                         48.0            22.265168       21.913896              0.015937      -0.127802  LINEAR-2
# 120                         50.0            22.262139       21.925328              0.015281      -0.116370  LINEAR-2
#
# [121 rows x 6 columns]

# %% [markdown]
# ***
# # Memory and space of this dictinary:

# %%
def get_deep_size(obj, seen=None):
    """Recursively find the size of the object and all its contents."""
    size = sys.getsizeof(obj)
    if seen is None:
        seen = set()

    obj_id = id(obj)
    if obj_id in seen:
        return 0

    seen.add(obj_id)

    if isinstance(obj, dict):
        size += sum(get_deep_size(k, seen) + get_deep_size(v, seen) for k, v in obj.items())

    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum(get_deep_size(i, seen) for i in obj)

    return size

dict_size_bytes = get_deep_size(experiments_process_and_results)
dict_size_gb = dict_size_bytes / (1024 * 1024 * 1024) 
print(f"The dictionary uses {dict_size_gb:.2f} GB of memory.")
# Out:
# The dictionary uses 2.75 GB of memory.

# %%
# Save the dictionary to a file
with open('experiments_process_and_results.pkl', 'wb') as f:
    pickle.dump(experiments_process_and_results, f)

# Get the size of the file in bytes
file_size_bytes = os.path.getsize('experiments_process_and_results.pkl')

# Convert the size to MB or GB if needed
file_size_mb = file_size_bytes / (1024 * 1024)  # Convert bytes to MB
file_size_gb = file_size_bytes / (1024 * 1024 * 1024)  # Convert bytes to GB

# print(f"The dictionary takes {file_size_mb:.2f} MB of disk space.")
print(f"The dictionary takes {file_size_gb:.2f} GB of disk space.")

# Optionally, delete the file after checking its size
# os.remove('experiments_process_and_results.pkl')
# Out:
# The dictionary takes 0.61 GB of disk space.

# %%
# Path to the .pkl file
file_path = 'experiments_process_and_results.pkl'

# Load the dictionary from the file
with open(file_path, 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict['Exp_46']['geometry_features'][loaded_dict['Exp_46']['geometry_features'].Feature == 'LINEAR-1']
# Out:
#     Angle[degree]ORDistance[mm]  Secondary-axis [mm]  Main-axis [mm]  Out-of-roundness [-]  Collapse [mm]   Feature
# 46                          2.0            22.162259       21.906534              0.011665      -0.015107  LINEAR-1
# 47                          4.0            22.190288       22.110636              0.003633       0.188994  LINEAR-1
# 48                          6.0            22.186960       21.870702              0.014427      -0.050939  LINEAR-1
# 49                          8.0            22.173423       21.717551              0.020796      -0.204091  LINEAR-1
# 50                         10.0            22.141711       21.882052              0.011845      -0.039589  LINEAR-1
# 51                         12.0            22.098264       21.961980              0.006217       0.040339  LINEAR-1
# 52                         14.0            22.061047       21.993668              0.003074       0.072026  LINEAR-1
# 53                         16.0            22.029402       22.033260             -0.000176       0.111618  LINEAR-1
# 54                         18.0            22.005202       22.082635             -0.003532       0.160994  LINEAR-1
# 55                         20.0            21.992852       22.119149             -0.005761       0.197508  LINEAR-1
# 56                         22.0            21.981131       22.141420             -0.007312       0.219778  LINEAR-1
# 57                         24.0            21.987313       22.157262             -0.007753       0.235620  LINEAR-1
# 58                         26.0            21.991787       22.172755             -0.008255       0.251113  LINEAR-1
# 59                         28.0            22.007811       22.177274             -0.007730       0.255633  LINEAR-1
# 60                         30.0            22.021535       22.171803             -0.006855       0.250161  LINEAR-1
# 61                         32.0            22.035694       22.165392             -0.005916       0.243751  LINEAR-1
# 62                         34.0            22.050115       22.147749             -0.004454       0.226108  LINEAR-1
# 63                         36.0            22.055181       22.143234             -0.004017       0.221592  LINEAR-1
# 64                         38.0            22.067789       22.135859             -0.003105       0.214217  LINEAR-1
# 65                         40.0            22.084943       22.117688             -0.001494       0.196046  LINEAR-1
# 66                         42.0            22.098440       22.100389             -0.000089       0.178748  LINEAR-1
# 67                         44.0            22.113590       22.101356              0.000558       0.179714  LINEAR-1
# 68                         46.0            22.122573       22.102169              0.000931       0.180528  LINEAR-1
# 69                         48.0            22.133285       22.087652              0.002082       0.166010  LINEAR-1
# 70                         50.0            22.135685       22.074080              0.002810       0.152439  LINEAR-1
# 71                         52.0            22.137868       22.067341              0.003217       0.145700  LINEAR-1
# 72                         54.0            22.145277       22.058751              0.003947       0.137109  LINEAR-1
# 73                         56.0            22.152966       22.051394              0.004633       0.129752  LINEAR-1
# 74                         58.0            22.162285       22.046275              0.005292       0.124633  LINEAR-1
# 75                         60.0            22.150780       22.033397              0.005355       0.111755  LINEAR-1
# 76                         62.0            22.153217       22.034212              0.005429       0.112571  LINEAR-1
# 77                         64.0            22.160555       22.032593              0.005837       0.110951  LINEAR-1
# 78                         66.0            22.166327       22.030205              0.006209       0.108563  LINEAR-1
# 79                         68.0            22.185147       22.030266              0.007065       0.108624  LINEAR-1
# 80                         70.0            22.174280       22.015084              0.007262       0.093442  LINEAR-1
# 81                         72.0            22.180513       22.007232              0.007905       0.085591  LINEAR-1
# 82                         74.0            22.179852       22.001903              0.008118       0.080262  LINEAR-1
# 83                         76.0            22.180037       21.993241              0.008521       0.071599  LINEAR-1
# 84                         78.0            22.186031       21.999216              0.008522       0.077575  LINEAR-1
# 85                         80.0            22.186260       22.009732              0.008053       0.088090  LINEAR-1
# 86                         82.0            22.192832       22.007688              0.008446       0.086047  LINEAR-1
# 87                         84.0            22.180187       22.004870              0.007997       0.083229  LINEAR-1
# 88                         86.0            22.183069       21.996216              0.008524       0.074575  LINEAR-1
# 89                         88.0            22.198367       22.001958              0.008960       0.080316  LINEAR-1
# 90                         90.0            22.203810       21.994516              0.009547       0.072874  LINEAR-1
# 91                         92.0            22.199354       21.990645              0.009521       0.069004  LINEAR-1
# 92                         94.0            22.205470       21.998131              0.009458       0.076490  LINEAR-1
# 93                         96.0            22.207984       22.000413              0.009469       0.078772  LINEAR-1
# 94                         98.0            22.201899       21.998882              0.009261       0.077240  LINEAR-1
# 95                        100.0            22.199015       21.996424              0.009242       0.074782  LINEAR-1
